# %%
# !pip3 install aiogram
# !pip3 install nest_asyncio
# !pip3 install aiohttp-socks
# !pip3 install websocket-client

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

# %%
import json
from aiogram import Bot, types
from aiogram.dispatcher import Dispatcher
from aiogram.utils import executor
from aiogram import types
from aiogram.types import ReplyKeyboardRemove, \
    ReplyKeyboardMarkup, KeyboardButton, \
    InlineKeyboardMarkup, InlineKeyboardButton
import nest_asyncio
import datetime
import requests
import logging
import threading
from bot_get_signal import trader
TOKEN = '5250393085:AAGj3EE7cEd3yhgHn2M4Yqd7wr7pxz734JA'
star = "✨"
lover = "🥰"
# bot = Bot(token=TOKEN)
proxy = 'socks5://127.0.0.1:9150'
bot = Bot(TOKEN, proxy=proxy)
dp = Dispatcher(bot)

logging.basicConfig(level=logging.INFO)
log = logging.getLogger('broadcast')

users={'hossain1993':{'api_key':'62e3e694054f1e0001127930' , 'api_secret' : 'a75605e8-aea9-4eb3-bc2a-d90c0c063a3f',
    'api_passphrase' : '92237302790','balance_trade':100,'username_trader':'hossain1993',
                      'username_user':'hossain1993','trader_code':1,'bot_code':1,'proxy':None}}

# json.dump(users, open('users.json','w'))
try:
    propertis={'password':'','username':'','trader_code':0,'bot_code':0,'addres_wallet':'',
    'state_user':'-','expire_Data':'','telegram_username':'','Register':False,'trader':False,'is_bot':False }
    nowtext = json.load(open('nowtext.json'))
    profile_account = json.load(open('profile_account.json'))
#     print(profile_account)
#     print(nowtext)
except Exception as error:
    print(1)
    nowtext={}
    profile_account={}
print(profile_account)
@dp.message_handler(commands=['start'])
async def registration(message: types.Message):
    global propertis
    global nowtext
    global profile_account
    print(profile_account)
    print(message.from_id,[*profile_account])
    print(str(message.from_id) not in profile_account)

    if str(message.from_id) not in profile_account:
        profile_account[str(message.from_id)]=propertis.copy()
        profile_account[str(message.from_id)]['telegram_username']=message.from_user['username']
        profile_account[str(message.from_id)]['is_bot']=message.from_user['is_bot']
    if profile_account[str(message.from_id)]['Register']==True:
        buttons = ['درباره ربات','درباره ما','ارتباط با ما','اصلاح مشخصات',"شارژ باقی مانده","من تریدر هستم","معاملات خودکار با ربات",'ویرایش' ]
    else:
        buttons = ['ثبت نام','درباره ربات','درباره ما','ارتباط با ما','اصلاح مشخصات',"شارژ باقی مانده","من تریدر هستم","معاملات خودکار با ربات",'ویرایش' ]
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    keyboard.add(*buttons)
    await message.answer("سلام✨\nما با شما هستیم که بیشترین سودها را در بازارهای مالی داشته باشید ربات مجموعه ما فعلا بر روی صرافی کوکوین فعال هست و در آینده نچندان دور این ربات در صرافی های معتبر دیگر فعال خواهد\n" + lover, reply_markup=keyboard)

@dp.message_handler(lambda message: message.text in [".","Menu"])
async def registration(message: types.Message):
    global nowtext
    global profile_account
    if profile_account[str(message.from_id)]['Register']==True:
        keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
        buttons = ['درباره ربات','درباره ما','ارتباط با ما','اصلاح مشخصات',"شارژ باقی مانده","من تریدر هستم","معاملات خودکار با ربات",'ویرایش']
        keyboard.add(*buttons)
        await message.answer('یکی از گزینه های زیر را انتخاب کنید',reply_markup=keyboard)
    else:
        await message.answer('لطفا در ابتدا ثبت نام نمایید   \n /start')

@dp.message_handler(lambda message: message.text in ["ثبت نام"])
async def registration(message: types.Message):
    global nowtext
    global profile_account
    if profile_account[str(message.from_id)]['Register']==False:
        nowtext[str(message.from_id)]=message.text

        await message.answer('لطفا یک نام کاربری برای خود انتخاب کنید و بفرستید سپس با زدن دکمه رمز، کلمه رمز را بفرستید (توجه داشته باشید که شما با همین نام کاربری و رمز خدمات خواهید گرفت)')
    else:await message.answer('شما قبلا ثبت نام کردید')

@dp.message_handler(lambda message: message.text in ["رمز"])
async def registration(message: types.Message):
    global nowtext
    global profile_account
    if profile_account[str(message.from_id)]['username']!='':
        nowtext[str(message.from_id)]=message.text
        await message.answer('رمز خود را وارد کنید و سپس کلید منو را بزنید (رمز شما باید حداقل دارای 8 کاراکتر باشد)')

@dp.message_handler(lambda message: message.text in ["ویرایش"])
async def registration(message: types.Message):
    global nowtext
    global profile_account
    if profile_account[str(message.from_id)]['Register']==True:
        keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
        nowtext[str(message.from_id)]=message.text
        buttons = ['ویرایش آدرس کیف پول']
        keyboard.add(*buttons)
    else:  
        await message.answer('لطفا در ابتدا ثبت نام نمایید   \n /start')

@dp.message_handler(lambda message: message.text in ["ویرایش آدرس کیف پول"])
async def registration(message: types.Message):
    global nowtext
    global profile_account
    if profile_account[str(message.from_id)]['Register']==True:
        keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
        nowtext[str(message.from_id)]=message.text
        buttons = ['Menu','نام کاربری']
        keyboard.add(*buttons)
        await message.answer('لطفا آدرس کیف پول خود را وارد کنید',reply_markup=keyboard)
    else:
        await message.answer('لطفا در ابتدا ثبت نام نمایید   \n /start')

@dp.message_handler(lambda message: message.text in ["ارتباط با ما"])
async def registration(message: types.Message):
    global nowtext
    global profile_account
    keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
    nowtext[str(message.from_id)]=message.text
    buttons = ['Menu']
    keyboard.add(*buttons)
    await message.answer('برای انتقادات و مشکلات ربات یا طرح نظرات خود با آیدی زیر در ارتباط شوید',reply_markup=keyboard)
    await message.answer('https://t.me/future0bot')

@dp.message_handler(lambda message: message.text == "شارژ باقی مانده")
async def registration(message: types.Message):
    global nowtext
    global profile_account
    if profile_account[str(message.from_id)]['state_user']==1:
        await message.answer('زمان باقی مانده شما در تاریخ و زمان %s به پایان میرسد' % (profile_account[str(message.from_id)]['expire_Data']))
    else:
        keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
        buttons = ["معاملات خودکار با ربات"]
        keyboard.add(*buttons)
        await message.answer('لطفا ابتدا برای خرید ربات اقدام نمایید     \n /start ',reply_markup=keyboard)

@dp.message_handler(lambda message: message.text == "من تریدر هستم" )
async def registration(message: types.Message):
    print(1)
    global nowtext
    print(1)
    try:
        print(json.load(open('profile_account.json')))
        print(profile_account[str(message.from_id)])
    except Exception as error:
        print(error)
    print(1)
    
    print(1)
    print(profile_account[str(message.from_id)]['Register'] , True)
    if profile_account[str(message.from_id)]['Register']==True:
        nowtext[str(message.from_id)]=message.text
        keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
        buttons = ["من تایید نشدم"]
        keyboard.add(*buttons)
        await message.answer('لطفا گزینه زیر را انتخاب کنید',reply_markup=keyboard)
    else:
        await message.answer('لطفا در ابتدا ثبت نام نمایید   \n /start')

@dp.message_handler(lambda message : message.text in ["من تایید نشدم"])
async def registration(message: types.Message):
    global nowtext
    global profile_account
    if nowtext[str(message.from_id)]!="من تریدر هستم":
        await message.answer('لطفا مراحل را از ابتدا انجام دهید')
    if profile_account[str(message.from_id)]['Register']==True:
        keyboard = types.InlineKeyboardMarkup()
        button = InlineKeyboardButton('کانال تایید صلاحیت', url='https://t.me/+beYCa8fOxmYyMzc0')
        keyboard.add(button)
        await message.answer("لطفا وارد کانال زیر شوید و تایید صلاحیت خودتان را انجام دهید. و منتظر باشید تا تایید شوید ",reply_markup=keyboard)
        await bot.send_message('91652281', 'new trader: %s' % (profile_account[str(message.from_id)]['username']))
    else:
        await message.answer('لطفا در ابتدا ثبت نام نمایید   \n /start')

@dp.message_handler(lambda message: message.text == "معاملات خودکار با ربات" )
async def registration(message: types.Message):
    global nowtext
    global profile_account
    nowtext[str(message.from_id)]=message.text
    if profile_account[str(message.from_id)]['Register']==True:
        keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
        buttons = ["kucoin"]
        keyboard.add(*buttons)
        await message.answer("لطفا در یکی از صرافی های مورد پوشش ربات ما عضو شوید و مقدارهای مورد نظر را با انتخاب یکی از صرافی های پایین به ربات ارائه دهید", reply_markup=keyboard)
    else:
        await message.answer('لطفا در ابتدا ثبت نام نمایید   \n /start')

@dp.message_handler(lambda message: message.text == "kucoin")
async def registration(message: types.Message):
    global nowtext
    global profile_account
    if nowtext[str(message.from_id)]!="معاملات خودکار با ربات":
        await message.answer('لطفا مراحل را از ابتدا انجام دهید')
    elif profile_account[str(message.from_id)]['Register']==True:
        keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
        nowtext[str(message.from_id)]=message.text
        buttons = ["من ربات را خریدم"]
        keyboard.add(*buttons)
        await message.answer("برای استفاده از ربات نیاز هست تا هر دو ماه ربات را به مبلغ 15 دلار شارژ کنید و سپس آدرس کیف پول خودتان را برای ما بفرستید تا صحت انجام تراکنش را بررسی کنیم (لطفا دقت داشته باشید که آدرس کیف پول را به صورت صحیح وارد کنید چون که در غیر این صورت واریزی شما قابل پیگیری نیست)", reply_markup=keyboard)    
        await message.answer("لطفا برای شارژ حساب خودتان به آدرس کیف پول زیر مبلغ مورد نظر را واریز کنید (توجه کنید که پول را بر بستر BEP20 واریز کنید و فقط استیبل کوین USDT واریز کنید) ")
        await message.answer('0x262e0274c88182a01363bd9aec68d1d654510512')
        await message.answer('بعد از مراحل بالا دکمه (من ربات را خریدم فشار دهید و منتظر تایید شدن باشید)')
    else:
        await message.answer('لطفا در ابتدا ثبت نام نمایید   \n /start')

@dp.message_handler(lambda message: message.text == "من ربات را خریدم")
async def registration(message: types.Message):
    global nowtext
    global profile_account
    if nowtext[str(message.from_id)]!="kucoin":
        await message.answer('لطفا مراحل را از ابتدا انجام دهید')
    elif profile_account[str(message.from_id)]['Register']==True:
        nowtext[str(message.from_id)]=message.text
    # اول دستی واریزها رو چک کنیم تا بدونیم اون عدد چطوری بدست بیاریم
        # ch=check_wallet()
        # if ch=='ok':
        #     keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
        #     nowtext[str(message.from_id)]=message.text
        #     buttons = ["Menu"]
        #     keyboard.add(*buttons)
        await message.answer("لطفا در صرافی کوکوین ثبت نام نمایید و مقدارهای خواسته شده را مانند زیر برای ما تهیه نمایید ( براکت را کپی کنید و مقدار هر کدام را رو به روی آن بنویسید) \n توجه داشته باشید که مقدار سرمایه حداقل برای انجام ترید ربات برای شما 50 دلار میباشد")#, reply_markup=keyboard)
        await bot.send_message('91652281', 'new user: %s' % (profile_account[str(message.from_id)]['username']))
        await message.answer('{"api_key":"" ,"api_secret":"" ,"api_passphrase":"" , "your_trader":"" }')
        await message.answer('همچنین در قسمت your_trade اسم تریدر خودتان را انتخاب کنید')
    else:
        await message.answer('لطفا در ابتدا ثبت نام نمایید   \n /start')

@dp.message_handler(lambda message: message.text == "trade" )
async def registration(message: types.Message):
    global nowtext
    global profile_account
    nowtext[str(message.from_id)]=message.text
    if (profile_account[str(message.from_id)]['Register']==True) and (profile_account[str(message.from_id)]['trader_code']==1):
        one_lot=10 # xrp
        symbol='XRPUSDTM'
        commission=0.001
        rond=4
        username=profile_account[str(message.from_id)]['username']
        trade=trader( rond=rond , commission=commission , symbol=symbol , one_lot=one_lot , limit=None , timeframe=None , username=username)
        thread=threading.Thread(target=trade.control_position)
        thread.start()
        detail_accuonts=json.load(open('detail_accuonts_%s.json' % (username)))
        if len([*detail_accuonts])>0:
            await message.answer("لطفا مقدار لوریج و حد سود متحرک را وارد کنید مطابق زیر. مقدار حد ضرر به طور خودکار توسط ادمین تنظیم شده و مقدار آن برابر 0.03 نقطه ورود هست")
            await message.answer("{'leverage':'','stop_trail':'' ,'':''}")
            await message.answer( 'و در صورتی که بخواهید به صورت دستی معامله را ببندید یا حد ضرر آن را جا به جا کنید از فرمت زیر استفاده کنید')
            await message.answer("{'stopPrice_sl': (مقدار 0 یا 1), 'stop_trail': (مقدار 0 یا 1)}")
#---------------------------------------------------------------------
@dp.message_handler(lambda message: message.text in ["تایید یوزر جدید"])
async def registration(message: types.Message):
    global nowtext
    nowtext[str(message.from_id)]=message.text
    await message.answer('لطفا آیدی یوزر مورد نظر را وارد کنید')

@dp.message_handler(lambda message: message.text in ["تایید تریدر جدید"])
async def registration(message: types.Message):
    global nowtext
    nowtext[str(message.from_id)]=message.text
    await message.answer('لطفا آیدی تریدر مورد نظر را وارد کنید')

@dp.message_handler(lambda message: message.text in ["talk with users"])
async def registration(message: types.Message):
  # این برای موقعی هست  که کاربر بگه من پول واریز کردم اما واریزی نداشته باشه
    global nowtext
    nowtext[str(message.from_id)]=message.text
    await message.answer('لطفا آیدی کاربر را بفرستید')
    
@dp.message_handler(regexp='[\w|\W]')
async def savefilters(message: types.update):
    global nowtext
    global profile_account
    if str(message.from_id) in nowtext:
        print(nowtext[str(message.from_id)])
    else:
        nowtext[str(message.from_id)]=''
    json.dump(nowtext, open('nowtext.json', 'w'))
    print('**')
#-------------------------------------------------------------------------------------------
    if nowtext[str(message.from_id)]=="trade":
        print(1)
        try:
            payam=json.loads(message.text)
        except Exception as error:
            await bot.send_message(message.from_id,'لطفا مقدار صحیح وارد نمایید')
            pass
        detail_accuonts=json.load(open('detail_accuonts_%s.json' % (username)))
        if (len([*detail_accuonts])>0) and (profile_account[str(message.from_id)]['trader_code']==1) :
            if type(payam)==dict:
                if len(payam)==3:
                    if ('leverage' in payam) and ('stop_trail' in payam):
                        username=profile_account[str(message.from_id)]['username']
                        entry_trader = json.load( open( "entry_trader_%s.json" %(username) ) )
                        entry_trader['leverage']=int(payam['leverage'])
                        entry_trader['st']=payam['stop_trail']
                        json.dump(entry_trader, open('entry_trader_%s.json' %(username), 'w'))
                    else:
                        await bot.send_message(message.from_id,'لطفا مقدار صحیح وارد نمایید')

            if type(payam)==dict:
                if len(payam)==2:
                    if ('stopPrice_sl' in payam) and ('stop_trail' in payam):
                        username=profile_account[str(message.from_id)]['username']
                        entry_trader = json.load( open( "entry_trader_%s.json" %(username) ) )
                        entry_trader['stopPrice_sl']=int(payam['stopPrice_sl'])
                        entry_trader['stop_trail']=int(payam['stop_trail'])
                        json.dump(entry_trader, open('entry_trader_%s.json' %(username), 'w'))
                    else:
                        await bot.send_message(message.from_id,'لطفا مقدار صحیح وارد نمایید')
        else:
            await bot.send_message(message.from_id,'لطفا اول تایید خودتان را بگیرید. همچنین شما باید تعداد بیشتر از 5 کاربر داشته باشید')
        
#-------------------------------------------------------------------------------------------
    elif nowtext[str(message.from_id)]=="ثبت نام":
        print(2)
        users=json.load(open('users.json'))
        if len(users)>0:
            if len([*{key:value for key,value in users.items() if value['username_user']==message.text}])==0:
                profile_account[str(message.from_id)]['username']=message.text

                new_user={'api_key':'' , 'api_secret' : '','api_passphrase' : '','balance_trade':100,
                          'username_trader':'','username_user':'','trader_code':0,'bot_code':0,'proxy':None}
                new_user['username_user']=message.text
                users[message.text]=new_user.copy()
                json.dump(users, open('users.json','w'))
            else:
                await message.answer("لطفا نام کاربری تکراری وارد نکنید")
        else:
            profile_account[str(message.from_id)]['username']=message.text

            new_user={"api_key": "", "api_secret": "", "api_passphrase": "",
            "balance_trade": 100,'username_trader':'','username_user':''}
            new_user['username_user']=message.text
            users[message.text]=new_user.copy()
            json.dump(users, open('users.json','w'))
        keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
        buttons = ['رمز']
        keyboard.add(*buttons)
        await bot.send_message(message.from_id,"لطفا کلید رمز را بزنید", reply_markup=keyboard)
        print(profile_account)
#-------------------------------------------------------------------------------------------
    elif nowtext[str(message.from_id)]=="رمز":
        print(3)
        if len(message.text.replace(" ", ""))>=8:
            profile_account[str(message.from_id)]['password']=message.text
            profile_account[str(message.from_id)]['Register']=True
            keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
            buttons = ['Menu']
            keyboard.add(*buttons)
            await message.answer('سپاس از صبوری شما و ثبت نام ',reply_markup=keyboard)
        else:
            await message.answer("لطفا رمز صحیح وارد کنید (حداقل دارای 8 کاراکتر باشد و بدون فاصله) ")
#-------------------------------------------------------------------------------------------
    elif nowtext[str(message.from_id)]=="kucoin":
        print(4)
        profile_account[str(message.from_id)]['addres_wallet']=message.text

    elif nowtext[str(message.from_id)]=="ویرایش آدرس کیف پول":
        print(5)
        profile_account[str(message.from_id)]['addres_wallet']=message.text
#-------------------------------------------------------------------------------------------
    elif nowtext[str(message.from_id)]=="من ربات را خریدم":
        print(6)
        print(type(message.text))
        print(message.text)
        try:
            
            payam=json.loads(message.text)
        except Exception as error:
            await bot.send_message(message.from_id,'لطفا مقدار صحیح وارد نمایید')
            pass

        if type(payam)==dict:
            if len(payam)==4:
                if ("api_key" in payam) and ("api_secret" in payam) and ("api_passphrase" in payam) and ('your_trader' in payam):
                    users=json.load(open('users.json'))

                    if len([*{key:value for key,value in users.items() if value['username_trader']==payam['your_trader']}])>0:

                        
                        print(1)
                        username=profile_account[str(message.from_id)]['username']
                        users[username]["username_trader"]=str(payam["your_trader"])
                        print(2)
                        users[username]["api_secret"]=str(payam["api_secret"])
                        print(3)
                        users[username]["api_passphrase"]=str(payam["api_passphrase"])
                        print(4)
                        users[username]["api_key"]=str(payam["api_key"])
                        print(5)
                        json.dump(users, open('users.json','w'))
                        keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
                        buttons = ['Menu']
                        keyboard.add(*buttons)
                        await message.answer("منتظر معاملات تریدر باشید", reply_markup=keyboard)
                    else:
                        await message.answer("اسم تریدر موجود نیست")
                else:
                    await message.answer("اطلاعات درست وارد کنید")
            else:
                await message.answer("اطلاعات درست وارد کنید")

#-------------------------------------------------------------------------------------------
    elif nowtext[str(message.from_id)]=="تایید یوزر جدید":
        nowtext[str(message.from_id)]=''
        print(8)
        for i in profile_account:
              if profile_account[i]['username']==message.text:
                id_user=i
                break
        profile_account[id_user]['bot_code']=1
        users=json.load(open('users.json'))
        username=profile_account[id_user]['username']
        users[username]['bot_code']=1
        json.dump(users, open('users.json','w'))
        profile_account[id_user]['expire_Data']=str((datetime.datetime.utcnow() + datetime.timedelta(days=60)))
        await bot.send_message(int(id_user), 'تایید صلاحیت شدید. لطفا در اکانت صرافی خود حداقل مقدار 100 دلار داشته باشید و به صورت ارز USDT باشد')
#-------------------------------------------------------------------------------------------
    elif nowtext[str(message.from_id)]=="تایید تریدر جدید":
        nowtext[str(message.from_id)]=''
        print(9)
        for i in profile_account:
              if profile_account[i]['username']==message.text:
                id_user=i
                break
        print(9)
        profile_account[id_user]['trader_code']=1
        users=json.load(open('users.json'))
        username=profile_account[id_user]['username']
        users[username]['trader_code']=1
        print(9)
        json.dump(users, open('users.json','w'))
        await bot.send_message(int(id_user), 'لطفا تعداد کاربرهای خودتان را به عدد 5 برسانید تا اجازه ترید داشته باشید')
        await bot.send_message(int(id_user), ' از این پس با فرستادن کلمه trade شما میتوانید از ربات معاملات خودکار استفاده کنید')
#-------------------------------------------------------------------------------------------
    elif nowtext[str(message.from_id)]=="talk with users":
        nowtext[str(message.from_id)]=''
        print(10)
        for i in profile_account:
              if profile_account[i]['username']==message.text:
                id_user=i
                break
        await bot.send_message(int(id_user),'لطفا در ابتدا اشتراک تهیه بفرمایید')
#-------------------------------------------------------------------------------------------

#-------------------------------------------------------------------------------------------
    elif str(message.from_id) not in [" تایید یوزر جدید","تایید تریدر جدید","talk with users"]:
        if str(message.from_id) in ['91652281']:
            print(7)
            keyboard = types.ReplyKeyboardMarkup(resize_keyboard=True)
            buttons = [" تایید یوزر جدید","تایید تریدر جدید","talk with users"]
            keyboard.add(*buttons)
            await message.answer("سلام ادمین", reply_markup=keyboard)
            
    json.dump(profile_account, open('profile_account.json', 'w')) # جای اینو عوض کن 
    

if __name__ == '__main__':
    nest_asyncio.apply()
   # __import__('IPython').embed()
    executor.start_polling(dp)
